# %% [markdown]
# # Explainable Heart Disease Risk Prediction — Training Notebook
# This notebook mirrors the project training pipeline. The production training logic is kept in `scripts/train_model.py` so it can be reproduced from the command line.

# %%
from pathlib import Path
import pandas as pd

DATA = Path('../data/heart.csv')
df = pd.read_csv(DATA)
df.head()

# %%
df.shape, df.isna().sum(), df['target'].value_counts(dropna=False)

# %% [markdown]
# ## Train and compare models
# The script compares Logistic Regression, Random Forest and XGBoost using Accuracy, Precision, Recall, F1, ROC-AUC, plus 5-fold cross-validation.

# %%
# %run ../scripts/train_model.py

# %% [markdown]
# After training, open `../app/models/metadata.json` to inspect the model comparison and the selected deployment model.
